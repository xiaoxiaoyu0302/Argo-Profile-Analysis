# %%
import netCDF4 as nc
from netCDF4 import Dataset
from datetime import datetime, timedelta
import numpy as np
import matplotlib.pyplot as plt
import seawater as csr
from matplotlib import cm

# %%
nc1=Dataset('20070811120000-REMSS-L4_GHRSST-SSTfnd-MW_OI-GLOB-v02.0-fv05.0.nc')
nc2=Dataset('20070821120000-REMSS-L4_GHRSST-SSTfnd-MW_OI-GLOB-v02.0-fv05.0.nc')

# %%
# nc1.set_auto_mask(False)

# %%
lat=nc1.variables['lat'][:]
lon=nc1.variables['lon'][:]
lon[300:500]
# Out:
# masked_array(data=[-104.875, -104.625, -104.375, -104.125, -103.875,
#                    -103.625, -103.375, -103.125, -102.875, -102.625,
#                    -102.375, -102.125, -101.875, -101.625, -101.375,
#                    -101.125, -100.875, -100.625, -100.375, -100.125,
#                     -99.875,  -99.625,  -99.375,  -99.125,  -98.875,
#                     -98.625,  -98.375,  -98.125,  -97.875,  -97.625,
#                     -97.375,  -97.125,  -96.875,  -96.625,  -96.375,
#                     -96.125,  -95.875,  -95.625,  -95.375,  -95.125,
#                     -94.875,  -94.625,  -94.375,  -94.125,  -93.875,
#                     -93.625,  -93.375,  -93.125,  -92.875,  -92.625,
#                     -92.375,  -92.125,  -91.875,  -91.625,  -91.375,
#                     -91.125,  -90.875,  -90.625,  -90.375,  -90.125,
#                     -89.875,  -89.625,  -89.375,  -89.125,  -88.875,
#                     -88.625,  -88.375,  -88.125,  -87.875,  -87.625,
#                     -87.375,  -87.125,  -86.875,  -86.625,  -86.375,
#                     -86.125,  -85.875,  -85.625,  -85.375,  -85.125,
#                     -84.875,  -84.625,  -84.375,  -84.125,  -83.875,
#                     -83.625,  -83.375,  -83.125,  -82.875,  -82.625,
#                     -82.375,  -82.125,  -81.875,  -81.625,  -81.375,
#                     -81.125,  -80.875,  -80.625,  -80.375,  -80.125,
#                     -79.875,  -79.625,  -79.375,  -79.125,  -78.875,
#                     -78.625,  -78.375,  -78.125,  -77.875,  -77.625,
#                     -77.375,  -77.125,  -76.875,  -76.625,  -76.375,
#                     -76.125,  -75.875,  -75.625,  -75.375,  -75.125,
#                     -74.875,  -74.625,  -74.375,  -74.125,  -73.875,
#                     -73.625,  -73.375,  -73.125,  -72.875,  -72.625,
#                     -72.375,  -72.125,  -71.875,  -71.625,  -71.375,
#                     -71.125,  -70.875,  -70.625,  -70.375,  -70.125,
#                     -69.875,  -69.625,  -69.375,  -69.125,  -68.875,
#                     -68.625,  -68.375,  -68.125,  -67.875,  -67.625,
#                     -67.375,  -67.125,  -66.875,  -66.625,  -66.375,
#                     -66.125,  -65.875,  -65.625,  -65.375,  -65.125,
#                     -64.875,  -64.625,  -64.375,  -64.125,  -63.875,
#                     -63.625,  -63.375,  -63.125,  -62.875,  -62.625,
#                     -62.375,  -62.125,  -61.875,  -61.625,  -61.375,
#                     -61.125,  -60.875,  -60.625,  -60.375,  -60.125,
#                     -59.875,  -59.625,  -59.375,  -59.125,  -58.875,
#                     -58.625,  -58.375,  -58.125,  -57.875,  -57.625,
#                     -57.375,  -57.125,  -56.875,  -56.625,  -56.375,
#                     -56.125,  -55.875,  -55.625,  -55.375,  -55.125],
#              mask=False,
#        fill_value=1e+20,
#             dtype=float32)

# %%
# Out:
# 687

# %%
indlat1=np.where(lat==-10.125)[0][0]
indlat2=np.where(lat==22.625)[0][0]
indlon1=np.where(lon==-90.125)[0][0]
indlon2=np.where(lon==-8.125)[0][0]
sst1=nc1.variables['analysed_sst'][0,indlat1:indlat2,indlon1:indlon2]-273.15
sst2=nc2.variables['analysed_sst'][0,indlat1:indlat2,indlon1:indlon2]-273.15
lat1=lat[indlat1:indlat2]
lon1=lon[indlon1:indlon2]
sst=sst2-sst1

# %%
fig=plt.figure(figsize=(14,6))
X,Y=np.meshgrid(lon1,lat1)
ax=fig.add_subplot(1,1,1)
p=ax.pcolor(X,Y,sst,vmin=-2,vmax=2,cmap=cm.tab20b)
cb=fig.colorbar(p)

xh=[-41.3,-44.5,-47.9,-51.5,-55.14,-58.94,-62.1,-65.19,-67.81,-70.98,-74.3,-78.31,-82.30,-86.10]
yh=[12.16,12.6,13.0,13.58,14.19,14.54,14.98,15.160,15.509,15.77,16.38,16.81,17.76,20.41]
vmax=[31.64,36.24,32.28,43.36,42.87,41.48,40.31,46.14,54.13,64.34,61.70,66.18,66.05,50.95]
s = vmax*5
plt.scatter(xh, yh, s, c="k", marker='^',label="Dean track")
ax.set_title('Temp Difference From OISST Day 17-Day 14')
# Out:
# Text(0.5,1,'Temp Difference From OISST Day 17-Day 14')

# %%
fig=plt.figure(figsize=(14,6))
X,Y=np.meshgrid(lon1,lat1)
ax=fig.add_subplot(1,1,1)
p=ax.pcolor(X,Y,sst,vmin=-2,vmax=2,cmap=cm.tab20b)
cb=fig.colorbar(p)

xh=[-41.3,-44.5,-47.9,-51.5,-55.14,-58.94,-62.1,-65.19,-67.81,-70.98,-74.3,-78.31,-82.30,-86.10]
yh=[12.16,12.6,13.0,13.58,14.19,14.54,14.98,15.160,15.509,15.77,16.38,16.81,17.76,20.41]
vmax=[31.64,36.24,32.28,43.36,42.87,41.48,40.31,46.14,54.13,64.34,61.70,66.18,66.05,50.95]
s = vmax*5
plt.scatter(xh, yh, s, c="k", marker='^',label="Dean track")
ax.set_title('Temp Difference From OISST Day 21-Day 11')
# Out:
# Text(0.5,1,'Temp Difference From OISST Day 21-Day 11')

# %%
fig=plt.figure(figsize=(14,6))
X,Y=np.meshgrid(lon1,lat1)
ax=fig.add_subplot(1,1,1)
p=ax.pcolor(X,Y,sst,vmin=-2,vmax=2,cmap=cm.bwr)
cb=fig.colorbar(p)

xh=[-41.3,-44.5,-47.9,-51.5,-55.14,-58.94,-62.1,-65.19,-67.81,-70.98,-74.3,-78.31,-82.30,-86.10]
yh=[12.16,12.6,13.0,13.58,14.19,14.54,14.98,15.160,15.509,15.77,16.38,16.81,17.76,20.41]
vmax=[31.64,36.24,32.28,43.36,42.87,41.48,40.31,46.14,54.13,64.34,61.70,66.18,66.05,50.95]
s = vmax*5
plt.scatter(xh, yh, s, c="k", marker='^',label="Dean track")
ax.set_title('Temp Difference From OISST Day 21-Day 14')
# Out:
# Text(0.5,1,'Temp Difference From OISST Day 21-Day 14')

# %%
fig=plt.figure(figsize=(14,6))
X,Y=np.meshgrid(lon1,lat1)
ax=fig.add_subplot(1,1,1)
p=ax.pcolor(X,Y,sst,vmin=-2,vmax=2,cmap=cm.tab20b)
cb=fig.colorbar(p)

xh=[-41.3,-44.5,-47.9,-51.5,-55.14,-58.94,-62.1,-65.19,-67.81,-70.98,-74.3,-78.31,-82.30,-86.10]
yh=[12.16,12.6,13.0,13.58,14.19,14.54,14.98,15.160,15.509,15.77,16.38,16.81,17.76,20.41]
vmax=[31.64,36.24,32.28,43.36,42.87,41.48,40.31,46.14,54.13,64.34,61.70,66.18,66.05,50.95]
s = vmax*5
plt.scatter(xh, yh, s, c="k", marker='^',label="Dean track")
ax.set_title('Temp Difference From OISST Day 25-Day 14')
# Out:
# Text(0.5,1,'Temp Difference From OISST Day 25-Day 14')

# %%
fig=plt.figure(figsize=(14,6))
X,Y=np.meshgrid(lon1,lat1)
ax=fig.add_subplot(1,1,1)
p=ax.pcolor(X,Y,sst,vmin=-2,vmax=2,cmap=cm.tab20b)
cb=fig.colorbar(p)

xh=[-41.3,-44.5,-47.9,-51.5,-55.14,-58.94,-62.1,-65.19,-67.81,-70.98,-74.3,-78.31,-82.30,-86.10]
yh=[12.16,12.6,13.0,13.58,14.19,14.54,14.98,15.160,15.509,15.77,16.38,16.81,17.76,20.41]
vmax=[31.64,36.24,32.28,43.36,42.87,41.48,40.31,46.14,54.13,64.34,61.70,66.18,66.05,50.95]
s = vmax*5
plt.scatter(xh, yh, s, c="k", marker='^',label="Dean track")
ax.set_title('Temp Difference From OISST Day 28-Day 14')
# Out:
# Text(0.5,1,'Temp Difference From OISST Day 28-Day 14')

# %%
fig=plt.figure(figsize=(14,6))
X,Y=np.meshgrid(lon1,lat1)
ax=fig.add_subplot(1,1,1)
p=ax.pcolor(X,Y,sst,vmin=-2,vmax=2,cmap=cm.tab20b)
cb=fig.colorbar(p)

xh=[-41.3,-44.5,-47.9,-51.5,-55.14,-58.94,-62.1,-65.19,-67.81,-70.98,-74.3,-78.31,-82.30,-86.10]
yh=[12.16,12.6,13.0,13.58,14.19,14.54,14.98,15.160,15.509,15.77,16.38,16.81,17.76,20.41]
vmax=[31.64,36.24,32.28,43.36,42.87,41.48,40.31,46.14,54.13,64.34,61.70,66.18,66.05,50.95]
s = vmax*5
plt.scatter(xh, yh, s, c="k", marker='^',label="Dean track")
ax.set_title('Temp Difference From OISST Day Sep 14-Day Aug 28')
# Out:
# Text(0.5,1,'Temp Difference From OISST Day Sep 14-Day Aug 28')

# %%
fig=plt.figure(figsize=(14,6))
X,Y=np.meshgrid(lon1,lat1)
ax=fig.add_subplot(1,1,1)
p=ax.pcolor(X,Y,sst1, vmin=22, vmax=31,cmap=cm.tab20b)
cb=fig.colorbar(p)

xh=[-41.3,-44.5,-47.9,-51.5,-55.14,-58.94,-62.1,-65.19,-67.81,-70.98,-74.3,-78.31,-82.30,-86.10]
yh=[12.16,12.6,13.0,13.58,14.19,14.54,14.98,15.160,15.509,15.77,16.38,16.81,17.76,20.41]
vmax=[31.64,36.24,32.28,43.36,42.87,41.48,40.31,46.14,54.13,64.34,61.70,66.18,66.05,50.95]
s = vmax*5
plt.scatter(xh, yh, s, c="k", marker='^',label="Dean track")
ax.set_title('Temp on Day 14')
# Out:
# Text(0.5,1,'Temp on Day 14')

# %%
fig=plt.figure(figsize=(14,6))
X,Y=np.meshgrid(lon1,lat1)
ax=fig.add_subplot(1,1,1)
p=ax.pcolor(X,Y,sst2, vmin=22, vmax=31,cmap=cm.tab20b)
cb=fig.colorbar(p)

xh=[-41.3,-44.5,-47.9,-51.5,-55.14,-58.94,-62.1,-65.19,-67.81,-70.98,-74.3,-78.31,-82.30,-86.10]
yh=[12.16,12.6,13.0,13.58,14.19,14.54,14.98,15.160,15.509,15.77,16.38,16.81,17.76,20.41]
vmax=[31.64,36.24,32.28,43.36,42.87,41.48,40.31,46.14,54.13,64.34,61.70,66.18,66.05,50.95]
s = vmax*5
plt.scatter(xh, yh, s, c="k", marker='^',label="Dean track")
ax.set_title('Temp on Day 21')
# Out:
# Text(0.5,1,'Temp on Day 21')

# %%
def func(x, y):
     return x*(1-x)*np.cos(4*np.pi*x) * np.sin(4*np.pi*y**2)**2

# %%
grid_x, grid_y = np.mgrid[0:1:100j, 0:1:200j]

# %%
points = np.random.rand(1000, 2)
values = func(points[:,0], points[:,1])
np.shape(points)
# Out:
# (1000, 2)

# %%
# read the CRESM results
path_cresm="/localdata/xiaoxiaoyu/aoml3/"
nc_cresm3=Dataset(path_cresm+'TXGLO.ocn.hi.2007-08-14_21:00:00.nc')
nc_cresm2=Dataset(path_cresm+'TXGLO.ocn.hi.2007-08-20_21:00:00.nc')
temp_cresm3=nc_cresm3.variables["temp"][0,::-1,:,:]
temp_cresm2=nc_cresm2.variables["temp"][0,::-1,:,:]
salt_cresm3=nc_cresm3.variables["salt"][0,::-1,:,:]
salt_cresm2=nc_cresm2.variables["salt"][0,::-1,:,:]
temp_cresm3=np.squeeze(temp_cresm3)  #删除没有必要的维度
temp_cresm2=np.squeeze(temp_cresm2)
salt_cresm3=np.squeeze(salt_cresm3)
salt_cresm2=np.squeeze(salt_cresm2)

lat_cresm=nc_cresm2.variables["lat_rho"][:,0]
lon_cresm=nc_cresm2.variables["lon_rho"][0,:]
X,Y = np.meshgrid(lon, lat)

# %%
point=np.empty(len(lat_cresm))
points=np.array([lat_cresm[:],lon_cresm[:]])
np.shape(points[1])
points[1][0]
# Out:
# -83.0
